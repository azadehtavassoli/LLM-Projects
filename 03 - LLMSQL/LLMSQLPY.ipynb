# %%
# Import required libraries for database connection and data handling 
from sqlalchemy import create_engine
import pandas as pd

import os  # Import the os module to interact with the operating system
from dotenv import load_dotenv  # Import the load_dotenv function to load environment variables from a .env file

import openai  # Import the OpenAI library to interact with the OpenAI API

# %%
# Set up the connection string for SQL Server using SQLAlchemy
connection_string = (
    "mssql+pyodbc://"
    "DESKTOP-SNEPGI0/"  # Server name
    "AdventureWorks2019?"  # Database name
    "driver=ODBC+Driver+17+for+SQL+Server&"  # ODBC driver
    "trusted_connection=yes"  # Use Windows authentication
)

# Create a SQLAlchemy engine for managing the database connection
engine = create_engine(connection_string)

# Define a function to execute SQL queries
def execute_query(query, engine):
    """
    Executes an SQL query and returns the result as a DataFrame.
    """
    try:
        result_df = pd.read_sql(query, engine)
        return result_df
    except Exception as e:
        print(f"Error executing query: {e}")
        return None

# Test the function with a sample query
query = """
SELECT SalesOrderID, SubTotal, TaxAmt, Freight, TotalDue
FROM Sales.SalesOrderHeader
"""

#result = execute_query(query, engine)
df = execute_query(query, engine)
print(df.head())
#if result is not None:
    #print("Query Result:\n", result.head())
# Out:
#    SalesOrderID    SubTotal     TaxAmt   Freight    TotalDue
# 0         43659  20565.6206  1971.5149  616.0984  23153.2339
# 1         43660   1294.2529   124.2483   38.8276   1457.3288
# 2         43661  32726.4786  3153.7696  985.5530  36865.8012
# 3         43662  28832.5289  2775.1646  867.2389  32474.9324
# 4         43663    419.4589    40.2681   12.5838    472.3108

# %%
# # Load environment variables from a .env file
# load_dotenv('.env')

# # Retrieve the OpenAI API key from the environment variables
# openai_api_key = os.environ["OPENAI_API_KEY"]
# # Set the OpenAI API key
# openai.api_key = openai_api_key

# %%
schema_query = """
SELECT TABLE_SCHEMA,TABLE_NAME, COLUMN_NAME, DATA_TYPE
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_CATALOG = 'AdventureWorks2019';
"""
schema_result = execute_query(schema_query, engine)

if schema_result is not None:
    # Display the schema information
    schema_info = "\n".join(
        #f"{row['TABLE_NAME']}: {row['COLUMN_NAME']} ({row['DATA_TYPE']})"
        f"{row['TABLE_SCHEMA']}.{row['TABLE_NAME']}.{row['COLUMN_NAME']} ({row['DATA_TYPE']})"
                for _, row in schema_result.iterrows() 
    )
    print("Schema Information:")
    print(schema_info)
# Out:
# Schema Information:
# Sales.SalesTaxRate.SalesTaxRateID (int)
# Sales.SalesTaxRate.StateProvinceID (int)
# Sales.SalesTaxRate.TaxType (tinyint)
# Sales.SalesTaxRate.TaxRate (smallmoney)
# Sales.SalesTaxRate.Name (nvarchar)
# Sales.SalesTaxRate.rowguid (uniqueidentifier)
# Sales.SalesTaxRate.ModifiedDate (datetime)
# Sales.PersonCreditCard.BusinessEntityID (int)
# Sales.PersonCreditCard.CreditCardID (int)
# Sales.PersonCreditCard.ModifiedDate (datetime)
# Person.vAdditionalContactInfo.BusinessEntityID (int)
# Person.vAdditionalContactInfo.FirstName (nvarchar)
# Person.vAdditionalContactInfo.MiddleName (nvarchar)
# Person.vAdditionalContactInfo.LastName (nvarchar)
# Person.vAdditionalContactInfo.TelephoneNumber (nvarchar)
# Person.vAdditionalContactInfo.TelephoneSpecialInstructions (nvarchar)
# Person.vAdditionalContactInfo.Street (nvarchar)
# Person.vAdditionalContactInfo.City (nvarchar)
# Person.vAdditionalContactInfo.StateProvince (nvarchar)
# Person.vAdditionalContactInfo.PostalCode (nvarchar)
# Person.vAdditionalContactInfo.CountryRegion (nvarchar)
# Person.vAdditionalContactInfo.HomeAddressSpecialInstructions (nvarchar)
# Person.vAdditionalContactInfo.EMailAddress (nvarchar)
# Person.vAdditionalContactInfo.EMailSpecialInstructions (nvarchar)
# Person.vAdditionalContactInfo.EMailTelephoneNumber (nvarchar)
# Person.vAdditionalContactInfo.rowguid (uniqueidentifier)
# Person.vAdditionalContactInfo.ModifiedDate (datetime)
# Person.PersonPhone.BusinessEntityID (int)
# Person.PersonPhone.PhoneNumber (nvarchar)
# Person.PersonPhone.PhoneNumberTypeID (int)
# Person.PersonPhone.ModifiedDate (datetime)
# HumanResources.vEmployee.BusinessEntityID (int)
# HumanResources.vEmployee.Title (nvarchar)
# HumanResources.vEmployee.FirstName (nvarchar)
# HumanResources.vEmployee.MiddleName (nvarchar)
# HumanResources.vEmployee.LastName (nvarchar)
# HumanResources.vEmployee.Suffix (nvarchar)
# HumanResources.vEmployee.JobTitle (nvarchar)
# HumanResources.vEmployee.PhoneNumber (nvarchar)
# HumanResources.vEmployee.PhoneNumberType (nvarchar)
# HumanResources.vEmployee.EmailAddress (nvarchar)
# HumanResources.vEmployee.EmailPromotion (int)
# HumanResources.vEmployee.AddressLine1 (nvarchar)
# HumanResources.vEmployee.AddressLine2 (nvarchar)
# HumanResources.vEmployee.City (nvarchar)
# HumanResources.vEmployee.StateProvinceName (nvarchar)
# HumanResources.vEmployee.PostalCode (nvarchar)
# HumanResources.vEmployee.CountryRegionName (nvarchar)
# HumanResources.vEmployee.AdditionalContactInfo (xml)
# Sales.SalesTerritory.TerritoryID (int)
# Sales.SalesTerritory.Name (nvarchar)
# Sales.SalesTerritory.CountryRegionCode (nvarchar)
# Sales.SalesTerritory.Group (nvarchar)
# Sales.SalesTerritory.SalesYTD (money)
# Sales.SalesTerritory.SalesLastYear (money)
# Sales.SalesTerritory.CostYTD (money)
# Sales.SalesTerritory.CostLastYear (money)
# Sales.SalesTerritory.rowguid (uniqueidentifier)
# Sales.SalesTerritory.ModifiedDate (datetime)
# HumanResources.vEmployeeDepartment.BusinessEntityID (int)
# HumanResources.vEmployeeDepartment.Title (nvarchar)
# HumanResources.vEmployeeDepartment.FirstName (nvarchar)
# HumanResources.vEmployeeDepartment.MiddleName (nvarchar)
# HumanResources.vEmployeeDepartment.LastName (nvarchar)
# HumanResources.vEmployeeDepartment.Suffix (nvarchar)
# HumanResources.vEmployeeDepartment.JobTitle (nvarchar)
# HumanResources.vEmployeeDepartment.Department (nvarchar)
# HumanResources.vEmployeeDepartment.GroupName (nvarchar)
# HumanResources.vEmployeeDepartment.StartDate (date)
# Person.PhoneNumberType.PhoneNumberTypeID (int)
# Person.PhoneNumberType.Name (nvarchar)
# Person.PhoneNumberType.ModifiedDate (datetime)
# HumanResources.vEmployeeDepartmentHistory.BusinessEntityID (int)
# HumanResources.vEmployeeDepartmentHistory.Title (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.FirstName (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.MiddleName (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.LastName (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.Suffix (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.Shift (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.Department (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.GroupName (nvarchar)
# HumanResources.vEmployeeDepartmentHistory.StartDate (date)
# HumanResources.vEmployeeDepartmentHistory.EndDate (date)
# Sales.vIndividualCustomer.BusinessEntityID (int)
# Sales.vIndividualCustomer.Title (nvarchar)
# Sales.vIndividualCustomer.FirstName (nvarchar)
# Sales.vIndividualCustomer.MiddleName (nvarchar)
# Sales.vIndividualCustomer.LastName (nvarchar)
# Sales.vIndividualCustomer.Suffix (nvarchar)
# Sales.vIndividualCustomer.PhoneNumber (nvarchar)
# Sales.vIndividualCustomer.PhoneNumberType (nvarchar)
# Sales.vIndividualCustomer.EmailAddress (nvarchar)
# Sales.vIndividualCustomer.EmailPromotion (int)
# Sales.vIndividualCustomer.AddressType (nvarchar)
# Sales.vIndividualCustomer.AddressLine1 (nvarchar)
# Sales.vIndividualCustomer.AddressLine2 (nvarchar)
# Sales.vIndividualCustomer.City (nvarchar)
# Sales.vIndividualCustomer.StateProvinceName (nvarchar)
# Sales.vIndividualCustomer.PostalCode (nvarchar)
# Sales.vIndividualCustomer.CountryRegionName (nvarchar)
# Sales.vIndividualCustomer.Demographics (xml)
# Production.Product.ProductID (int)
# Production.Product.Name (nvarchar)
# Production.Product.ProductNumber (nvarchar)
# Production.Product.MakeFlag (bit)
# Production.Product.FinishedGoodsFlag (bit)
# Production.Product.Color (nvarchar)
# Production.Product.SafetyStockLevel (smallint)
# Production.Product.ReorderPoint (smallint)
# Production.Product.StandardCost (money)
# Production.Product.ListPrice (money)
# Production.Product.Size (nvarchar)
# Production.Product.SizeUnitMeasureCode (nchar)
# Production.Product.WeightUnitMeasureCode (nchar)
# Production.Product.Weight (decimal)
# Production.Product.DaysToManufacture (int)
# Production.Product.ProductLine (nchar)
# Production.Product.Class (nchar)
# Production.Product.Style (nchar)
# Production.Product.ProductSubcategoryID (int)
# Production.Product.ProductModelID (int)
# Production.Product.SellStartDate (datetime)
# Production.Product.SellEndDate (datetime)
# Production.Product.DiscontinuedDate (datetime)
# Production.Product.rowguid (uniqueidentifier)
# Production.Product.ModifiedDate (datetime)
# Sales.vPersonDemographics.BusinessEntityID (int)
# Sales.vPersonDemographics.TotalPurchaseYTD (money)
# Sales.vPersonDemographics.DateFirstPurchase (datetime)
# Sales.vPersonDemographics.BirthDate (datetime)
# Sales.vPersonDemographics.MaritalStatus (nvarchar)
# Sales.vPersonDemographics.YearlyIncome (nvarchar)
# Sales.vPersonDemographics.Gender (nvarchar)
# Sales.vPersonDemographics.TotalChildren (int)
# Sales.vPersonDemographics.NumberChildrenAtHome (int)
# Sales.vPersonDemographics.Education (nvarchar)
# Sales.vPersonDemographics.Occupation (nvarchar)
# Sales.vPersonDemographics.HomeOwnerFlag (bit)
# Sales.vPersonDemographics.NumberCarsOwned (int)
# HumanResources.vJobCandidate.JobCandidateID (int)
# HumanResources.vJobCandidate.BusinessEntityID (int)
# HumanResources.vJobCandidate.Name.Prefix (nvarchar)
# HumanResources.vJobCandidate.Name.First (nvarchar)
# HumanResources.vJobCandidate.Name.Middle (nvarchar)
# HumanResources.vJobCandidate.Name.Last (nvarchar)
# HumanResources.vJobCandidate.Name.Suffix (nvarchar)
# HumanResources.vJobCandidate.Skills (nvarchar)
# HumanResources.vJobCandidate.Addr.Type (nvarchar)
# HumanResources.vJobCandidate.Addr.Loc.CountryRegion (nvarchar)
# HumanResources.vJobCandidate.Addr.Loc.State (nvarchar)
# HumanResources.vJobCandidate.Addr.Loc.City (nvarchar)
# HumanResources.vJobCandidate.Addr.PostalCode (nvarchar)
# HumanResources.vJobCandidate.EMail (nvarchar)
# HumanResources.vJobCandidate.WebSite (nvarchar)
# HumanResources.vJobCandidate.ModifiedDate (datetime)
# HumanResources.vJobCandidateEmployment.JobCandidateID (int)
# HumanResources.vJobCandidateEmployment.Emp.StartDate (datetime)
# HumanResources.vJobCandidateEmployment.Emp.EndDate (datetime)
# HumanResources.vJobCandidateEmployment.Emp.OrgName (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.JobTitle (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.Responsibility (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.FunctionCategory (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.IndustryCategory (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.Loc.CountryRegion (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.Loc.State (nvarchar)
# HumanResources.vJobCandidateEmployment.Emp.Loc.City (nvarchar)
# HumanResources.vJobCandidateEducation.JobCandidateID (int)
# HumanResources.vJobCandidateEducation.Edu.Level (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.StartDate (datetime)
# HumanResources.vJobCandidateEducation.Edu.EndDate (datetime)
# HumanResources.vJobCandidateEducation.Edu.Degree (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.Major (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.Minor (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.GPA (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.GPAScale (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.School (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.Loc.CountryRegion (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.Loc.State (nvarchar)
# HumanResources.vJobCandidateEducation.Edu.Loc.City (nvarchar)
# Production.vProductAndDescription.ProductID (int)
# Production.vProductAndDescription.Name (nvarchar)
# Production.vProductAndDescription.ProductModel (nvarchar)
# Production.vProductAndDescription.CultureID (nchar)
# Production.vProductAndDescription.Description (nvarchar)
# Production.vProductModelCatalogDescription.ProductModelID (int)
# Production.vProductModelCatalogDescription.Name (nvarchar)
# Production.vProductModelCatalogDescription.Summary (nvarchar)
# Production.vProductModelCatalogDescription.Manufacturer (nvarchar)
# Production.vProductModelCatalogDescription.Copyright (nvarchar)
# Production.vProductModelCatalogDescription.ProductURL (nvarchar)
# Production.vProductModelCatalogDescription.WarrantyPeriod (nvarchar)
# Production.vProductModelCatalogDescription.WarrantyDescription (nvarchar)
# Production.vProductModelCatalogDescription.NoOfYears (nvarchar)
# Production.vProductModelCatalogDescription.MaintenanceDescription (nvarchar)
# Production.vProductModelCatalogDescription.Wheel (nvarchar)
# Production.vProductModelCatalogDescription.Saddle (nvarchar)
# Production.vProductModelCatalogDescription.Pedal (nvarchar)
# Production.vProductModelCatalogDescription.BikeFrame (nvarchar)
# Production.vProductModelCatalogDescription.Crankset (nvarchar)
# Production.vProductModelCatalogDescription.PictureAngle (nvarchar)
# Production.vProductModelCatalogDescription.PictureSize (nvarchar)
# Production.vProductModelCatalogDescription.ProductPhotoID (nvarchar)
# Production.vProductModelCatalogDescription.Material (nvarchar)
# Production.vProductModelCatalogDescription.Color (nvarchar)
# Production.vProductModelCatalogDescription.ProductLine (nvarchar)
# Production.vProductModelCatalogDescription.Style (nvarchar)
# Production.vProductModelCatalogDescription.RiderExperience (nvarchar)
# Production.vProductModelCatalogDescription.rowguid (uniqueidentifier)
# Production.vProductModelCatalogDescription.ModifiedDate (datetime)
# Production.vProductModelInstructions.ProductModelID (int)
# Production.vProductModelInstructions.Name (nvarchar)
# Production.vProductModelInstructions.Instructions (nvarchar)
# Production.vProductModelInstructions.LocationID (int)
# Production.vProductModelInstructions.SetupHours (decimal)
# Production.vProductModelInstructions.MachineHours (decimal)
# Production.vProductModelInstructions.LaborHours (decimal)
# Production.vProductModelInstructions.LotSize (int)
# Production.vProductModelInstructions.Step (nvarchar)
# Production.vProductModelInstructions.rowguid (uniqueidentifier)
# Production.vProductModelInstructions.ModifiedDate (datetime)
# Sales.vSalesPerson.BusinessEntityID (int)
# Sales.vSalesPerson.Title (nvarchar)
# Sales.vSalesPerson.FirstName (nvarchar)
# Sales.vSalesPerson.MiddleName (nvarchar)
# Sales.vSalesPerson.LastName (nvarchar)
# Sales.vSalesPerson.Suffix (nvarchar)
# Sales.vSalesPerson.JobTitle (nvarchar)
# Sales.vSalesPerson.PhoneNumber (nvarchar)
# Sales.vSalesPerson.PhoneNumberType (nvarchar)
# Sales.vSalesPerson.EmailAddress (nvarchar)
# Sales.vSalesPerson.EmailPromotion (int)
# Sales.vSalesPerson.AddressLine1 (nvarchar)
# Sales.vSalesPerson.AddressLine2 (nvarchar)
# Sales.vSalesPerson.City (nvarchar)
# Sales.vSalesPerson.StateProvinceName (nvarchar)
# Sales.vSalesPerson.PostalCode (nvarchar)
# Sales.vSalesPerson.CountryRegionName (nvarchar)
# Sales.vSalesPerson.TerritoryName (nvarchar)
# Sales.vSalesPerson.TerritoryGroup (nvarchar)
# Sales.vSalesPerson.SalesQuota (money)
# Sales.vSalesPerson.SalesYTD (money)
# Sales.vSalesPerson.SalesLastYear (money)
# Sales.SalesTerritoryHistory.BusinessEntityID (int)
# Sales.SalesTerritoryHistory.TerritoryID (int)
# Sales.SalesTerritoryHistory.StartDate (datetime)
# Sales.SalesTerritoryHistory.EndDate (datetime)
# Sales.SalesTerritoryHistory.rowguid (uniqueidentifier)
# Sales.SalesTerritoryHistory.ModifiedDate (datetime)
# Sales.vSalesPersonSalesByFiscalYears.SalesPersonID (int)
# Sales.vSalesPersonSalesByFiscalYears.FullName (nvarchar)
# Sales.vSalesPersonSalesByFiscalYears.JobTitle (nvarchar)
# Sales.vSalesPersonSalesByFiscalYears.SalesTerritory (nvarchar)
# Sales.vSalesPersonSalesByFiscalYears.2002 (money)
# Sales.vSalesPersonSalesByFiscalYears.2003 (money)
# Sales.vSalesPersonSalesByFiscalYears.2004 (money)
# Person.vStateProvinceCountryRegion.StateProvinceID (int)
# Person.vStateProvinceCountryRegion.StateProvinceCode (nchar)
# Person.vStateProvinceCountryRegion.IsOnlyStateProvinceFlag (bit)
# Person.vStateProvinceCountryRegion.StateProvinceName (nvarchar)
# Person.vStateProvinceCountryRegion.TerritoryID (int)
# Person.vStateProvinceCountryRegion.CountryRegionCode (nvarchar)
# Person.vStateProvinceCountryRegion.CountryRegionName (nvarchar)
# Sales.vStoreWithDemographics.BusinessEntityID (int)
# Sales.vStoreWithDemographics.Name (nvarchar)
# Sales.vStoreWithDemographics.AnnualSales (money)
# Sales.vStoreWithDemographics.AnnualRevenue (money)
# Sales.vStoreWithDemographics.BankName (nvarchar)
# Sales.vStoreWithDemographics.BusinessType (nvarchar)
# Sales.vStoreWithDemographics.YearOpened (int)
# Sales.vStoreWithDemographics.Specialty (nvarchar)
# Sales.vStoreWithDemographics.SquareFeet (int)
# Sales.vStoreWithDemographics.Brands (nvarchar)
# Sales.vStoreWithDemographics.Internet (nvarchar)
# Sales.vStoreWithDemographics.NumberEmployees (int)
# Sales.vStoreWithContacts.BusinessEntityID (int)
# Sales.vStoreWithContacts.Name (nvarchar)
# Sales.vStoreWithContacts.ContactType (nvarchar)
# Sales.vStoreWithContacts.Title (nvarchar)
# Sales.vStoreWithContacts.FirstName (nvarchar)
# Sales.vStoreWithContacts.MiddleName (nvarchar)
# Sales.vStoreWithContacts.LastName (nvarchar)
# Sales.vStoreWithContacts.Suffix (nvarchar)
# Sales.vStoreWithContacts.PhoneNumber (nvarchar)
# Sales.vStoreWithContacts.PhoneNumberType (nvarchar)
# Sales.vStoreWithContacts.EmailAddress (nvarchar)
# Sales.vStoreWithContacts.EmailPromotion (int)
# Production.ScrapReason.ScrapReasonID (smallint)
# Production.ScrapReason.Name (nvarchar)
# Production.ScrapReason.ModifiedDate (datetime)
# Sales.vStoreWithAddresses.BusinessEntityID (int)
# Sales.vStoreWithAddresses.Name (nvarchar)
# Sales.vStoreWithAddresses.AddressType (nvarchar)
# Sales.vStoreWithAddresses.AddressLine1 (nvarchar)
# Sales.vStoreWithAddresses.AddressLine2 (nvarchar)
# Sales.vStoreWithAddresses.City (nvarchar)
# Sales.vStoreWithAddresses.StateProvinceName (nvarchar)
# Sales.vStoreWithAddresses.PostalCode (nvarchar)
# Sales.vStoreWithAddresses.CountryRegionName (nvarchar)
# Purchasing.vVendorWithContacts.BusinessEntityID (int)
# Purchasing.vVendorWithContacts.Name (nvarchar)
# Purchasing.vVendorWithContacts.ContactType (nvarchar)
# Purchasing.vVendorWithContacts.Title (nvarchar)
# Purchasing.vVendorWithContacts.FirstName (nvarchar)
# Purchasing.vVendorWithContacts.MiddleName (nvarchar)
# Purchasing.vVendorWithContacts.LastName (nvarchar)
# Purchasing.vVendorWithContacts.Suffix (nvarchar)
# Purchasing.vVendorWithContacts.PhoneNumber (nvarchar)
# Purchasing.vVendorWithContacts.PhoneNumberType (nvarchar)
# Purchasing.vVendorWithContacts.EmailAddress (nvarchar)
# Purchasing.vVendorWithContacts.EmailPromotion (int)
# HumanResources.Shift.ShiftID (tinyint)
# HumanResources.Shift.Name (nvarchar)
# HumanResources.Shift.StartTime (time)
# HumanResources.Shift.EndTime (time)
# HumanResources.Shift.ModifiedDate (datetime)
# Purchasing.vVendorWithAddresses.BusinessEntityID (int)
# Purchasing.vVendorWithAddresses.Name (nvarchar)
# Purchasing.vVendorWithAddresses.AddressType (nvarchar)
# Purchasing.vVendorWithAddresses.AddressLine1 (nvarchar)
# Purchasing.vVendorWithAddresses.AddressLine2 (nvarchar)
# Purchasing.vVendorWithAddresses.City (nvarchar)
# Purchasing.vVendorWithAddresses.StateProvinceName (nvarchar)
# Purchasing.vVendorWithAddresses.PostalCode (nvarchar)
# Purchasing.vVendorWithAddresses.CountryRegionName (nvarchar)
# Production.ProductCategory.ProductCategoryID (int)
# Production.ProductCategory.Name (nvarchar)
# Production.ProductCategory.rowguid (uniqueidentifier)
# Production.ProductCategory.ModifiedDate (datetime)
# Purchasing.ShipMethod.ShipMethodID (int)
# Purchasing.ShipMethod.Name (nvarchar)
# Purchasing.ShipMethod.ShipBase (money)
# Purchasing.ShipMethod.ShipRate (money)
# Purchasing.ShipMethod.rowguid (uniqueidentifier)
# Purchasing.ShipMethod.ModifiedDate (datetime)
# Production.ProductCostHistory.ProductID (int)
# Production.ProductCostHistory.StartDate (datetime)
# Production.ProductCostHistory.EndDate (datetime)
# Production.ProductCostHistory.StandardCost (money)
# Production.ProductCostHistory.ModifiedDate (datetime)
# Production.ProductDescription.ProductDescriptionID (int)
# Production.ProductDescription.Description (nvarchar)
# Production.ProductDescription.rowguid (uniqueidentifier)
# Production.ProductDescription.ModifiedDate (datetime)
# Sales.ShoppingCartItem.ShoppingCartItemID (int)
# Sales.ShoppingCartItem.ShoppingCartID (nvarchar)
# Sales.ShoppingCartItem.Quantity (int)
# Sales.ShoppingCartItem.ProductID (int)
# Sales.ShoppingCartItem.DateCreated (datetime)
# Sales.ShoppingCartItem.ModifiedDate (datetime)
# Production.ProductDocument.ProductID (int)
# Production.ProductDocument.DocumentNode (hierarchyid)
# Production.ProductDocument.ModifiedDate (datetime)
# dbo.DatabaseLog.DatabaseLogID (int)
# dbo.DatabaseLog.PostTime (datetime)
# dbo.DatabaseLog.DatabaseUser (nvarchar)
# dbo.DatabaseLog.Event (nvarchar)
# dbo.DatabaseLog.Schema (nvarchar)
# dbo.DatabaseLog.Object (nvarchar)
# dbo.DatabaseLog.TSQL (nvarchar)
# dbo.DatabaseLog.XmlEvent (xml)
# Production.ProductInventory.ProductID (int)
# Production.ProductInventory.LocationID (smallint)
# Production.ProductInventory.Shelf (nvarchar)
# Production.ProductInventory.Bin (tinyint)
# Production.ProductInventory.Quantity (smallint)
# Production.ProductInventory.rowguid (uniqueidentifier)
# Production.ProductInventory.ModifiedDate (datetime)
# Sales.SpecialOffer.SpecialOfferID (int)
# Sales.SpecialOffer.Description (nvarchar)
# Sales.SpecialOffer.DiscountPct (smallmoney)
# Sales.SpecialOffer.Type (nvarchar)
# Sales.SpecialOffer.Category (nvarchar)
# Sales.SpecialOffer.StartDate (datetime)
# Sales.SpecialOffer.EndDate (datetime)
# Sales.SpecialOffer.MinQty (int)
# Sales.SpecialOffer.MaxQty (int)
# Sales.SpecialOffer.rowguid (uniqueidentifier)
# Sales.SpecialOffer.ModifiedDate (datetime)
# dbo.ErrorLog.ErrorLogID (int)
# dbo.ErrorLog.ErrorTime (datetime)
# dbo.ErrorLog.UserName (nvarchar)
# dbo.ErrorLog.ErrorNumber (int)
# dbo.ErrorLog.ErrorSeverity (int)
# dbo.ErrorLog.ErrorState (int)
# dbo.ErrorLog.ErrorProcedure (nvarchar)
# dbo.ErrorLog.ErrorLine (int)
# dbo.ErrorLog.ErrorMessage (nvarchar)
# Production.ProductListPriceHistory.ProductID (int)
# Production.ProductListPriceHistory.StartDate (datetime)
# Production.ProductListPriceHistory.EndDate (datetime)
# Production.ProductListPriceHistory.ListPrice (money)
# Production.ProductListPriceHistory.ModifiedDate (datetime)
# Person.Address.AddressID (int)
# Person.Address.AddressLine1 (nvarchar)
# Person.Address.AddressLine2 (nvarchar)
# Person.Address.City (nvarchar)
# Person.Address.StateProvinceID (int)
# Person.Address.PostalCode (nvarchar)
# Person.Address.SpatialLocation (geography)
# Person.Address.rowguid (uniqueidentifier)
# Person.Address.ModifiedDate (datetime)
# Sales.SpecialOfferProduct.SpecialOfferID (int)
# Sales.SpecialOfferProduct.ProductID (int)
# Sales.SpecialOfferProduct.rowguid (uniqueidentifier)
# Sales.SpecialOfferProduct.ModifiedDate (datetime)
# Production.ProductModel.ProductModelID (int)
# Production.ProductModel.Name (nvarchar)
# Production.ProductModel.CatalogDescription (xml)
# Production.ProductModel.Instructions (xml)
# Production.ProductModel.rowguid (uniqueidentifier)
# Production.ProductModel.ModifiedDate (datetime)
# Person.AddressType.AddressTypeID (int)
# Person.AddressType.Name (nvarchar)
# Person.AddressType.rowguid (uniqueidentifier)
# Person.AddressType.ModifiedDate (datetime)
# Person.StateProvince.StateProvinceID (int)
# Person.StateProvince.StateProvinceCode (nchar)
# Person.StateProvince.CountryRegionCode (nvarchar)
# Person.StateProvince.IsOnlyStateProvinceFlag (bit)
# Person.StateProvince.Name (nvarchar)
# Person.StateProvince.TerritoryID (int)
# Person.StateProvince.rowguid (uniqueidentifier)
# Person.StateProvince.ModifiedDate (datetime)
# Production.ProductModelIllustration.ProductModelID (int)
# Production.ProductModelIllustration.IllustrationID (int)
# Production.ProductModelIllustration.ModifiedDate (datetime)
# dbo.AWBuildVersion.SystemInformationID (tinyint)
# dbo.AWBuildVersion.Database Version (nvarchar)
# dbo.AWBuildVersion.VersionDate (datetime)
# dbo.AWBuildVersion.ModifiedDate (datetime)
# Production.ProductModelProductDescriptionCulture.ProductModelID (int)
# Production.ProductModelProductDescriptionCulture.ProductDescriptionID (int)
# Production.ProductModelProductDescriptionCulture.CultureID (nchar)
# Production.ProductModelProductDescriptionCulture.ModifiedDate (datetime)
# Production.BillOfMaterials.BillOfMaterialsID (int)
# Production.BillOfMaterials.ProductAssemblyID (int)
# Production.BillOfMaterials.ComponentID (int)
# Production.BillOfMaterials.StartDate (datetime)
# Production.BillOfMaterials.EndDate (datetime)
# Production.BillOfMaterials.UnitMeasureCode (nchar)
# Production.BillOfMaterials.BOMLevel (smallint)
# Production.BillOfMaterials.PerAssemblyQty (decimal)
# Production.BillOfMaterials.ModifiedDate (datetime)
# Sales.Store.BusinessEntityID (int)
# Sales.Store.Name (nvarchar)
# Sales.Store.SalesPersonID (int)
# Sales.Store.Demographics (xml)
# Sales.Store.rowguid (uniqueidentifier)
# Sales.Store.ModifiedDate (datetime)
# Production.ProductPhoto.ProductPhotoID (int)
# Production.ProductPhoto.ThumbNailPhoto (varbinary)
# Production.ProductPhoto.ThumbnailPhotoFileName (nvarchar)
# Production.ProductPhoto.LargePhoto (varbinary)
# Production.ProductPhoto.LargePhotoFileName (nvarchar)
# Production.ProductPhoto.ModifiedDate (datetime)
# Production.ProductProductPhoto.ProductID (int)
# Production.ProductProductPhoto.ProductPhotoID (int)
# Production.ProductProductPhoto.Primary (bit)
# Production.ProductProductPhoto.ModifiedDate (datetime)
# Production.TransactionHistory.TransactionID (int)
# Production.TransactionHistory.ProductID (int)
# Production.TransactionHistory.ReferenceOrderID (int)
# Production.TransactionHistory.ReferenceOrderLineID (int)
# Production.TransactionHistory.TransactionDate (datetime)
# Production.TransactionHistory.TransactionType (nchar)
# Production.TransactionHistory.Quantity (int)
# Production.TransactionHistory.ActualCost (money)
# Production.TransactionHistory.ModifiedDate (datetime)
# dbo.vw_RepeatPurchaseRate.RepeatPurchaseRate (float)
# Production.ProductReview.ProductReviewID (int)
# Production.ProductReview.ProductID (int)
# Production.ProductReview.ReviewerName (nvarchar)
# Production.ProductReview.ReviewDate (datetime)
# Production.ProductReview.EmailAddress (nvarchar)
# Production.ProductReview.Rating (int)
# Production.ProductReview.Comments (nvarchar)
# Production.ProductReview.ModifiedDate (datetime)
# Person.BusinessEntity.BusinessEntityID (int)
# Person.BusinessEntity.rowguid (uniqueidentifier)
# Person.BusinessEntity.ModifiedDate (datetime)
# Production.TransactionHistoryArchive.TransactionID (int)
# Production.TransactionHistoryArchive.ProductID (int)
# Production.TransactionHistoryArchive.ReferenceOrderID (int)
# Production.TransactionHistoryArchive.ReferenceOrderLineID (int)
# Production.TransactionHistoryArchive.TransactionDate (datetime)
# Production.TransactionHistoryArchive.TransactionType (nchar)
# Production.TransactionHistoryArchive.Quantity (int)
# Production.TransactionHistoryArchive.ActualCost (money)
# Production.TransactionHistoryArchive.ModifiedDate (datetime)
# Production.ProductSubcategory.ProductSubcategoryID (int)
# Production.ProductSubcategory.ProductCategoryID (int)
# Production.ProductSubcategory.Name (nvarchar)
# Production.ProductSubcategory.rowguid (uniqueidentifier)
# Production.ProductSubcategory.ModifiedDate (datetime)
# Person.BusinessEntityAddress.BusinessEntityID (int)
# Person.BusinessEntityAddress.AddressID (int)
# Person.BusinessEntityAddress.AddressTypeID (int)
# Person.BusinessEntityAddress.rowguid (uniqueidentifier)
# Person.BusinessEntityAddress.ModifiedDate (datetime)
# dbo.vw_SalesOrderHeader_Clean.SalesOrderID (int)
# dbo.vw_SalesOrderHeader_Clean.RevisionNumber (tinyint)
# dbo.vw_SalesOrderHeader_Clean.OrderDate (datetime)
# dbo.vw_SalesOrderHeader_Clean.DueDate (datetime)
# dbo.vw_SalesOrderHeader_Clean.ShipDate (datetime)
# dbo.vw_SalesOrderHeader_Clean.Status (tinyint)
# dbo.vw_SalesOrderHeader_Clean.OnlineOrderFlag (bit)
# dbo.vw_SalesOrderHeader_Clean.SalesOrderNumber (nvarchar)
# dbo.vw_SalesOrderHeader_Clean.PurchaseOrderNumber (nvarchar)
# dbo.vw_SalesOrderHeader_Clean.AccountNumber (nvarchar)
# dbo.vw_SalesOrderHeader_Clean.CustomerID (int)
# dbo.vw_SalesOrderHeader_Clean.SalesPersonID (int)
# dbo.vw_SalesOrderHeader_Clean.TerritoryID (int)
# dbo.vw_SalesOrderHeader_Clean.BillToAddressID (int)
# dbo.vw_SalesOrderHeader_Clean.ShipToAddressID (int)
# dbo.vw_SalesOrderHeader_Clean.ShipMethodID (int)
# dbo.vw_SalesOrderHeader_Clean.CreditCardID (int)
# dbo.vw_SalesOrderHeader_Clean.CreditCardApprovalCode (varchar)
# dbo.vw_SalesOrderHeader_Clean.CurrencyRateID (int)
# dbo.vw_SalesOrderHeader_Clean.SubTotal (money)
# dbo.vw_SalesOrderHeader_Clean.TaxAmt (money)
# dbo.vw_SalesOrderHeader_Clean.Freight (money)
# dbo.vw_SalesOrderHeader_Clean.TotalDue (money)
# dbo.vw_SalesOrderHeader_Clean.Comment (nvarchar)
# dbo.vw_SalesOrderHeader_Clean.rowguid (uniqueidentifier)
# dbo.vw_SalesOrderHeader_Clean.ModifiedDate (datetime)
# Purchasing.ProductVendor.ProductID (int)
# Purchasing.ProductVendor.BusinessEntityID (int)
# Purchasing.ProductVendor.AverageLeadTime (int)
# Purchasing.ProductVendor.StandardPrice (money)
# Purchasing.ProductVendor.LastReceiptCost (money)
# Purchasing.ProductVendor.LastReceiptDate (datetime)
# Purchasing.ProductVendor.MinOrderQty (int)
# Purchasing.ProductVendor.MaxOrderQty (int)
# Purchasing.ProductVendor.OnOrderQty (int)
# Purchasing.ProductVendor.UnitMeasureCode (nchar)
# Purchasing.ProductVendor.ModifiedDate (datetime)
# Person.BusinessEntityContact.BusinessEntityID (int)
# Person.BusinessEntityContact.PersonID (int)
# Person.BusinessEntityContact.ContactTypeID (int)
# Person.BusinessEntityContact.rowguid (uniqueidentifier)
# Person.BusinessEntityContact.ModifiedDate (datetime)
# dbo.vw_SalesOrderDetail_Clean.SalesOrderID (int)
# dbo.vw_SalesOrderDetail_Clean.SalesOrderDetailID (int)
# dbo.vw_SalesOrderDetail_Clean.CarrierTrackingNumber (nvarchar)
# dbo.vw_SalesOrderDetail_Clean.OrderQty (smallint)
# dbo.vw_SalesOrderDetail_Clean.ProductID (int)
# dbo.vw_SalesOrderDetail_Clean.SpecialOfferID (int)
# dbo.vw_SalesOrderDetail_Clean.UnitPrice (money)
# dbo.vw_SalesOrderDetail_Clean.UnitPriceDiscount (money)
# dbo.vw_SalesOrderDetail_Clean.LineTotal (numeric)
# dbo.vw_SalesOrderDetail_Clean.rowguid (uniqueidentifier)
# dbo.vw_SalesOrderDetail_Clean.ModifiedDate (datetime)
# Production.UnitMeasure.UnitMeasureCode (nchar)
# Production.UnitMeasure.Name (nvarchar)
# Production.UnitMeasure.ModifiedDate (datetime)
# dbo.vw_SalesOrderDetail_PositiveQuantities.SalesOrderID (int)
# dbo.vw_SalesOrderDetail_PositiveQuantities.SalesOrderDetailID (int)
# dbo.vw_SalesOrderDetail_PositiveQuantities.CarrierTrackingNumber (nvarchar)
# dbo.vw_SalesOrderDetail_PositiveQuantities.OrderQty (smallint)
# dbo.vw_SalesOrderDetail_PositiveQuantities.ProductID (int)
# dbo.vw_SalesOrderDetail_PositiveQuantities.SpecialOfferID (int)
# dbo.vw_SalesOrderDetail_PositiveQuantities.UnitPrice (money)
# dbo.vw_SalesOrderDetail_PositiveQuantities.UnitPriceDiscount (money)
# dbo.vw_SalesOrderDetail_PositiveQuantities.LineTotal (numeric)
# dbo.vw_SalesOrderDetail_PositiveQuantities.rowguid (uniqueidentifier)
# dbo.vw_SalesOrderDetail_PositiveQuantities.ModifiedDate (datetime)
# dbo.vw_SalesOrderDetail_NoOutliers.SalesOrderID (int)
# dbo.vw_SalesOrderDetail_NoOutliers.SalesOrderDetailID (int)
# dbo.vw_SalesOrderDetail_NoOutliers.CarrierTrackingNumber (nvarchar)
# dbo.vw_SalesOrderDetail_NoOutliers.OrderQty (smallint)
# dbo.vw_SalesOrderDetail_NoOutliers.ProductID (int)
# dbo.vw_SalesOrderDetail_NoOutliers.SpecialOfferID (int)
# dbo.vw_SalesOrderDetail_NoOutliers.UnitPrice (money)
# dbo.vw_SalesOrderDetail_NoOutliers.UnitPriceDiscount (money)
# dbo.vw_SalesOrderDetail_NoOutliers.LineTotal (numeric)
# dbo.vw_SalesOrderDetail_NoOutliers.rowguid (uniqueidentifier)
# dbo.vw_SalesOrderDetail_NoOutliers.ModifiedDate (datetime)
# Purchasing.Vendor.BusinessEntityID (int)
# Purchasing.Vendor.AccountNumber (nvarchar)
# Purchasing.Vendor.Name (nvarchar)
# Purchasing.Vendor.CreditRating (tinyint)
# Purchasing.Vendor.PreferredVendorStatus (bit)
# Purchasing.Vendor.ActiveFlag (bit)
# Purchasing.Vendor.PurchasingWebServiceURL (nvarchar)
# Purchasing.Vendor.ModifiedDate (datetime)
# Person.ContactType.ContactTypeID (int)
# Person.ContactType.Name (nvarchar)
# Person.ContactType.ModifiedDate (datetime)
# Sales.CountryRegionCurrency.CountryRegionCode (nvarchar)
# Sales.CountryRegionCurrency.CurrencyCode (nchar)
# Sales.CountryRegionCurrency.ModifiedDate (datetime)
# Person.CountryRegion.CountryRegionCode (nvarchar)
# Person.CountryRegion.Name (nvarchar)
# Person.CountryRegion.ModifiedDate (datetime)
# Production.WorkOrder.WorkOrderID (int)
# Production.WorkOrder.ProductID (int)
# Production.WorkOrder.OrderQty (int)
# Production.WorkOrder.StockedQty (int)
# Production.WorkOrder.ScrappedQty (smallint)
# Production.WorkOrder.StartDate (datetime)
# Production.WorkOrder.EndDate (datetime)
# Production.WorkOrder.DueDate (datetime)
# Production.WorkOrder.ScrapReasonID (smallint)
# Production.WorkOrder.ModifiedDate (datetime)
# Purchasing.PurchaseOrderDetail.PurchaseOrderID (int)
# Purchasing.PurchaseOrderDetail.PurchaseOrderDetailID (int)
# Purchasing.PurchaseOrderDetail.DueDate (datetime)
# Purchasing.PurchaseOrderDetail.OrderQty (smallint)
# Purchasing.PurchaseOrderDetail.ProductID (int)
# Purchasing.PurchaseOrderDetail.UnitPrice (money)
# Purchasing.PurchaseOrderDetail.LineTotal (money)
# Purchasing.PurchaseOrderDetail.ReceivedQty (decimal)
# Purchasing.PurchaseOrderDetail.RejectedQty (decimal)
# Purchasing.PurchaseOrderDetail.StockedQty (decimal)
# Purchasing.PurchaseOrderDetail.ModifiedDate (datetime)
# Sales.CreditCard.CreditCardID (int)
# Sales.CreditCard.CardType (nvarchar)
# Sales.CreditCard.CardNumber (nvarchar)
# Sales.CreditCard.ExpMonth (tinyint)
# Sales.CreditCard.ExpYear (smallint)
# Sales.CreditCard.ModifiedDate (datetime)
# Production.Culture.CultureID (nchar)
# Production.Culture.Name (nvarchar)
# Production.Culture.ModifiedDate (datetime)
# dbo.sysdiagrams.name (nvarchar)
# dbo.sysdiagrams.principal_id (int)
# dbo.sysdiagrams.diagram_id (int)
# dbo.sysdiagrams.version (int)
# dbo.sysdiagrams.definition (varbinary)
# Production.WorkOrderRouting.WorkOrderID (int)
# Production.WorkOrderRouting.ProductID (int)
# Production.WorkOrderRouting.OperationSequence (smallint)
# Production.WorkOrderRouting.LocationID (smallint)
# Production.WorkOrderRouting.ScheduledStartDate (datetime)
# Production.WorkOrderRouting.ScheduledEndDate (datetime)
# Production.WorkOrderRouting.ActualStartDate (datetime)
# Production.WorkOrderRouting.ActualEndDate (datetime)
# Production.WorkOrderRouting.ActualResourceHrs (decimal)
# Production.WorkOrderRouting.PlannedCost (money)
# Production.WorkOrderRouting.ActualCost (money)
# Production.WorkOrderRouting.ModifiedDate (datetime)
# Sales.Currency.CurrencyCode (nchar)
# Sales.Currency.Name (nvarchar)
# Sales.Currency.ModifiedDate (datetime)
# Purchasing.PurchaseOrderHeader.PurchaseOrderID (int)
# Purchasing.PurchaseOrderHeader.RevisionNumber (tinyint)
# Purchasing.PurchaseOrderHeader.Status (tinyint)
# Purchasing.PurchaseOrderHeader.EmployeeID (int)
# Purchasing.PurchaseOrderHeader.VendorID (int)
# Purchasing.PurchaseOrderHeader.ShipMethodID (int)
# Purchasing.PurchaseOrderHeader.OrderDate (datetime)
# Purchasing.PurchaseOrderHeader.ShipDate (datetime)
# Purchasing.PurchaseOrderHeader.SubTotal (money)
# Purchasing.PurchaseOrderHeader.TaxAmt (money)
# Purchasing.PurchaseOrderHeader.Freight (money)
# Purchasing.PurchaseOrderHeader.TotalDue (money)
# Purchasing.PurchaseOrderHeader.ModifiedDate (datetime)
# Sales.CurrencyRate.CurrencyRateID (int)
# Sales.CurrencyRate.CurrencyRateDate (datetime)
# Sales.CurrencyRate.FromCurrencyCode (nchar)
# Sales.CurrencyRate.ToCurrencyCode (nchar)
# Sales.CurrencyRate.AverageRate (money)
# Sales.CurrencyRate.EndOfDayRate (money)
# Sales.CurrencyRate.ModifiedDate (datetime)
# Sales.Customer.CustomerID (int)
# Sales.Customer.PersonID (int)
# Sales.Customer.StoreID (int)
# Sales.Customer.TerritoryID (int)
# Sales.Customer.AccountNumber (varchar)
# Sales.Customer.rowguid (uniqueidentifier)
# Sales.Customer.ModifiedDate (datetime)
# HumanResources.Department.DepartmentID (smallint)
# HumanResources.Department.Name (nvarchar)
# HumanResources.Department.GroupName (nvarchar)
# HumanResources.Department.ModifiedDate (datetime)
# Production.Document.DocumentNode (hierarchyid)
# Production.Document.DocumentLevel (smallint)
# Production.Document.Title (nvarchar)
# Production.Document.Owner (int)
# Production.Document.FolderFlag (bit)
# Production.Document.FileName (nvarchar)
# Production.Document.FileExtension (nvarchar)
# Production.Document.Revision (nchar)
# Production.Document.ChangeNumber (int)
# Production.Document.Status (tinyint)
# Production.Document.DocumentSummary (nvarchar)
# Production.Document.Document (varbinary)
# Production.Document.rowguid (uniqueidentifier)
# Production.Document.ModifiedDate (datetime)
# Sales.vw_EcommerceDashboard.SalesOrderID (int)
# Sales.vw_EcommerceDashboard.OrderDate (datetime)
# Sales.vw_EcommerceDashboard.ShipDate (datetime)
# Sales.vw_EcommerceDashboard.CustomerID (int)
# Sales.vw_EcommerceDashboard.CustomerName (nvarchar)
# Sales.vw_EcommerceDashboard.SalesTerritory (nvarchar)
# Sales.vw_EcommerceDashboard.ProductID (int)
# Sales.vw_EcommerceDashboard.ProductName (nvarchar)
# Sales.vw_EcommerceDashboard.ProductNumber (nvarchar)
# Sales.vw_EcommerceDashboard.Quantity (smallint)
# Sales.vw_EcommerceDashboard.UnitPrice (money)
# Sales.vw_EcommerceDashboard.TotalPrice (money)
# Sales.SalesOrderDetail.SalesOrderID (int)
# Sales.SalesOrderDetail.SalesOrderDetailID (int)
# Sales.SalesOrderDetail.CarrierTrackingNumber (nvarchar)
# Sales.SalesOrderDetail.OrderQty (smallint)
# Sales.SalesOrderDetail.ProductID (int)
# Sales.SalesOrderDetail.SpecialOfferID (int)
# Sales.SalesOrderDetail.UnitPrice (money)
# Sales.SalesOrderDetail.UnitPriceDiscount (money)
# Sales.SalesOrderDetail.LineTotal (numeric)
# Sales.SalesOrderDetail.rowguid (uniqueidentifier)
# Sales.SalesOrderDetail.ModifiedDate (datetime)
# Person.EmailAddress.BusinessEntityID (int)
# Person.EmailAddress.EmailAddressID (int)
# Person.EmailAddress.EmailAddress (nvarchar)
# Person.EmailAddress.rowguid (uniqueidentifier)
# Person.EmailAddress.ModifiedDate (datetime)
# HumanResources.Employee.BusinessEntityID (int)
# HumanResources.Employee.NationalIDNumber (nvarchar)
# HumanResources.Employee.LoginID (nvarchar)
# HumanResources.Employee.OrganizationNode (hierarchyid)
# HumanResources.Employee.OrganizationLevel (smallint)
# HumanResources.Employee.JobTitle (nvarchar)
# HumanResources.Employee.BirthDate (date)
# HumanResources.Employee.MaritalStatus (nchar)
# HumanResources.Employee.Gender (nchar)
# HumanResources.Employee.HireDate (date)
# HumanResources.Employee.SalariedFlag (bit)
# HumanResources.Employee.VacationHours (smallint)
# HumanResources.Employee.SickLeaveHours (smallint)
# HumanResources.Employee.CurrentFlag (bit)
# HumanResources.Employee.rowguid (uniqueidentifier)
# HumanResources.Employee.ModifiedDate (datetime)
# Sales.SalesOrderHeader.SalesOrderID (int)
# Sales.SalesOrderHeader.RevisionNumber (tinyint)
# Sales.SalesOrderHeader.OrderDate (datetime)
# Sales.SalesOrderHeader.DueDate (datetime)
# Sales.SalesOrderHeader.ShipDate (datetime)
# Sales.SalesOrderHeader.Status (tinyint)
# Sales.SalesOrderHeader.OnlineOrderFlag (bit)
# Sales.SalesOrderHeader.SalesOrderNumber (nvarchar)
# Sales.SalesOrderHeader.PurchaseOrderNumber (nvarchar)
# Sales.SalesOrderHeader.AccountNumber (nvarchar)
# Sales.SalesOrderHeader.CustomerID (int)
# Sales.SalesOrderHeader.SalesPersonID (int)
# Sales.SalesOrderHeader.TerritoryID (int)
# Sales.SalesOrderHeader.BillToAddressID (int)
# Sales.SalesOrderHeader.ShipToAddressID (int)
# Sales.SalesOrderHeader.ShipMethodID (int)
# Sales.SalesOrderHeader.CreditCardID (int)
# Sales.SalesOrderHeader.CreditCardApprovalCode (varchar)
# Sales.SalesOrderHeader.CurrencyRateID (int)
# Sales.SalesOrderHeader.SubTotal (money)
# Sales.SalesOrderHeader.TaxAmt (money)
# Sales.SalesOrderHeader.Freight (money)
# Sales.SalesOrderHeader.TotalDue (money)
# Sales.SalesOrderHeader.Comment (nvarchar)
# Sales.SalesOrderHeader.rowguid (uniqueidentifier)
# Sales.SalesOrderHeader.ModifiedDate (datetime)
# HumanResources.EmployeeDepartmentHistory.BusinessEntityID (int)
# HumanResources.EmployeeDepartmentHistory.DepartmentID (smallint)
# HumanResources.EmployeeDepartmentHistory.ShiftID (tinyint)
# HumanResources.EmployeeDepartmentHistory.StartDate (date)
# HumanResources.EmployeeDepartmentHistory.EndDate (date)
# HumanResources.EmployeeDepartmentHistory.ModifiedDate (datetime)
# HumanResources.EmployeePayHistory.BusinessEntityID (int)
# HumanResources.EmployeePayHistory.RateChangeDate (datetime)
# HumanResources.EmployeePayHistory.Rate (money)
# HumanResources.EmployeePayHistory.PayFrequency (tinyint)
# HumanResources.EmployeePayHistory.ModifiedDate (datetime)
# Sales.SalesOrderHeaderSalesReason.SalesOrderID (int)
# Sales.SalesOrderHeaderSalesReason.SalesReasonID (int)
# Sales.SalesOrderHeaderSalesReason.ModifiedDate (datetime)
# Sales.SalesPerson.BusinessEntityID (int)
# Sales.SalesPerson.TerritoryID (int)
# Sales.SalesPerson.SalesQuota (money)
# Sales.SalesPerson.Bonus (money)
# Sales.SalesPerson.CommissionPct (smallmoney)
# Sales.SalesPerson.SalesYTD (money)
# Sales.SalesPerson.SalesLastYear (money)
# Sales.SalesPerson.rowguid (uniqueidentifier)
# Sales.SalesPerson.ModifiedDate (datetime)
# Production.Illustration.IllustrationID (int)
# Production.Illustration.Diagram (xml)
# Production.Illustration.ModifiedDate (datetime)
# HumanResources.JobCandidate.JobCandidateID (int)
# HumanResources.JobCandidate.BusinessEntityID (int)
# HumanResources.JobCandidate.Resume (xml)
# HumanResources.JobCandidate.ModifiedDate (datetime)
# Production.Location.LocationID (smallint)
# Production.Location.Name (nvarchar)
# Production.Location.CostRate (smallmoney)
# Production.Location.Availability (decimal)
# Production.Location.ModifiedDate (datetime)
# Person.Password.BusinessEntityID (int)
# Person.Password.PasswordHash (varchar)
# Person.Password.PasswordSalt (varchar)
# Person.Password.rowguid (uniqueidentifier)
# Person.Password.ModifiedDate (datetime)
# Sales.SalesPersonQuotaHistory.BusinessEntityID (int)
# Sales.SalesPersonQuotaHistory.QuotaDate (datetime)
# Sales.SalesPersonQuotaHistory.SalesQuota (money)
# Sales.SalesPersonQuotaHistory.rowguid (uniqueidentifier)
# Sales.SalesPersonQuotaHistory.ModifiedDate (datetime)
# Person.Person.BusinessEntityID (int)
# Person.Person.PersonType (nchar)
# Person.Person.NameStyle (bit)
# Person.Person.Title (nvarchar)
# Person.Person.FirstName (nvarchar)
# Person.Person.MiddleName (nvarchar)
# Person.Person.LastName (nvarchar)
# Person.Person.Suffix (nvarchar)
# Person.Person.EmailPromotion (int)
# Person.Person.AdditionalContactInfo (xml)
# Person.Person.Demographics (xml)
# Person.Person.rowguid (uniqueidentifier)
# Person.Person.ModifiedDate (datetime)
# Sales.SalesReason.SalesReasonID (int)
# Sales.SalesReason.Name (nvarchar)
# Sales.SalesReason.ReasonType (nvarchar)
# Sales.SalesReason.ModifiedDate (datetime)

# %%
# Check for null values in the DataFrame and print the count of nulls for each column
if df is not None:
    print("Count of null values in each column:")
    print(df.isnull().sum())
# Out:
# Count of null values in each column:
# SalesOrderID    0
# SubTotal        0
# TaxAmt          0
# Freight         0
# TotalDue        0
# dtype: int64

# %%
# Identify rows with invalid values (negative SubTotal, TaxAmt, or Freight)
invalid_values = df[(df['SubTotal'] < 0) | (df['TaxAmt'] < 0) | (df['Freight'] < 0)]
print("Rows with invalid values:")
print(invalid_values)
# Out:
# Rows with invalid values:
# Empty DataFrame
# Columns: [SalesOrderID, SubTotal, TaxAmt, Freight, TotalDue]
# Index: []

# %%
def split_schema_into_chunks(schema_info, max_tokens=1000):
    chunks = []
    current_chunk = []
    current_length = 0

    for line in schema_info.split("\n"):
        line_length = len(line.split())
        if current_length + line_length > max_tokens:
            chunks.append("\n".join(current_chunk))
            current_chunk = []
            current_length = 0

        current_chunk.append(line)
        current_length += line_length

    if current_chunk:
        chunks.append("\n".join(current_chunk))
    return chunks

# %%
# Load environment variables from a .env file
load_dotenv('.env')

# Retrieve the OpenAI API key from the environment variables
openai_api_key = os.environ["OPENAI_API_KEY"]
# Set the OpenAI API key
openai.api_key = openai_api_key

# %%
# def natural_to_sql(question, database_name="AdventureWorks2019"):
#     """
#     Convert a natural language question about the AdventureWorks database to SQL using GPT-4.
    
#     Parameters:
#     question (str): The natural language question to convert to SQL.
#     database_name (str): The name of the database to query. Default is "AdventureWorks2019".
    
#     Returns:
#     str: The SQL query generated by GPT-4.
#     """
#     # Create a chat completion request to the OpenAI API using the GPT-4 model
#     # client = openai.Client()
#     response = openai.chat.completions.create(
#         model="gpt-4",
#         messages=[
#             {
#                 "role": "system",
#                 "content": (
#                     f"You are a SQL assistant for the {database_name} database. "
#                     f"Here is the schema of the database:\n{schema_info}\n"
#                     "Your task is to generate only the SQL query for the following request. Do not include any text, explanation, or additional characters."
#                 )
#             },
#             {"role": "user", "content": f"Generate only a single SQL query for this question whitout any explanation: {question}"}
#         ]
#     )
#     # Return the generated SQL query from the response
#     return response.choices[0].message.content
#     #print(response.choices[0].message.content)

# %%
def natural_to_sql(question, schema_chunks, database_name="AdventureWorks2019"):
    generated_queries = []
    client = openai.Client()
    for idx, chunk in enumerate(schema_chunks):
        try:
            response = openai.chat.completions.create(
                model="gpt-4",
                messages=[
                    {
                        "role": "system",
                        "content": (
                            f"You are a SQL assistant for the {database_name} database. "
                            f"Here is part of the database schema:\n{chunk}\n"
                            "Your task is to generate only the SQL query for the following request. Do not include any text, explanation, or additional characters."
                        )
                    },
                    {"role": "user", "content": question}
                ]
            )
            query = response.choices[0].message.content #response["choices"][0]["message"]["content"]
            generated_queries.append(query)
        except Exception as e:
            print(f"Error during query generation: {e}")

    final_query = "\n".join(generated_queries)
    return final_query

# %%
# Example usage:
question ="What was the sales volume of the best product in each region in year 2011?"
#print("Question:", question)
sql_query = natural_to_sql(question, schema_chunks = split_schema_into_chunks(schema_info))
print(sql_query)
# Out:
# SELECT
#     R.Name AS RegionName,
#     P.Name AS ProductName,
#     MAX(OD.OrderQty) AS SalesVolume
# FROM
#     Sales.SalesOrderDetail AS OD
# JOIN
#     Sales.SalesOrderHeader AS OH
#     ON OD.SalesOrderID = OH.SalesOrderID
# JOIN
#     Sales.SalesTerritory AS R
#     ON OH.TerritoryID = R.TerritoryID
# JOIN
#     Production.Product AS P
#     ON OD.ProductID = P.ProductID
# WHERE
#     YEAR(OH.OrderDate) = 2011
# GROUP BY
#     R.Name,
#     P.Name;
# SELECT
#     S.TerritoryID,
#     sd.ProductID,
#     SUM(sd.OrderQty) as SalesVolume
# FROM
#     Sales.SalesOrderHeader AS S
# JOIN
#     Sales.SalesOrderDetail AS sd
# ON
#     S.SalesOrderID = sd.SalesOrderID
# WHERE
#     YEAR(S.OrderDate) = 2011
# GROUP BY
#     S.TerritoryID,
#     sd.ProductID
# ORDER BY
#     SalesVolume DESC;

# %%
def execute_query(query, engine):
    """
    Executes an SQL query and returns the result as a DataFrame.
    """
    try:
        result_df = pd.read_sql(query, engine)
        return result_df
    except Exception as e:
        print(f"Error executing query: {e}")
        return None

# %%
result = execute_query(sql_query, engine)
if result is not None:
        print("Query Result:\n", result)
# Out:
# Query Result:
#           RegionName                     ProductName  SalesVolume
# 0           Germany              Road-650 Black, 52            1
# 1           Germany              Road-650 Black, 62            1
# 2    United Kingdom                Road-150 Red, 44            1
# 3         Northwest           Sport-100 Helmet, Red           10
# 4            Canada         LL Road Frame - Red, 52            1
# ..              ...                             ...          ...
# 416       Northwest                Road-450 Red, 58            5
# 417       Southwest         LL Road Frame - Red, 62            5
# 418       Southwest   HL Mountain Frame - Black, 48            3
# 419       Southwest  HL Mountain Frame - Silver, 48            4
# 420       Southwest                Road-150 Red, 56            5
#
# [421 rows x 3 columns]
